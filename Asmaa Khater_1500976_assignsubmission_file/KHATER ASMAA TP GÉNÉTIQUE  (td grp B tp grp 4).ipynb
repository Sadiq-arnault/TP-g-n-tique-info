# %% [markdown]
# ASMAA KHATER n°12306025 TP GRP B

# %%
import numpy as np
import matplotlib.pyplot as plt

rmax = 0.2  # taux de croissance maximal (h⁻¹)
C0 = 0.1  # Concentration des cellules bactériennes au début de la simulation (10^3 cellules.mL-1)
T = 10 # durée totale de la simulation (heures)
dt = 0.1 # pas de temps (heures)
N_steps = int(T / dt)

time = np.linspace(0, T, N_steps)
C = C0 * np.exp(rmax * time)

plt.title('vitesse de croissance de la population globale en (10^3 cellules.mL-1.heure-1)')  # Titre du graphique
plt.plot(time, C, label='courbe 1') # Nom de la courbe
plt.xlabel('t(en h)') # Axe des X
plt.ylabel('C(10³cellules.mL-3)') # Axe des Y
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# comment s’appelle ce type de courbe ?
# il s'agit d'une courbe exponentielle on observe une cocnentration qui augmente en fonction du temps de manière exponentielle .
# En combien de temps la population double ?
# la concentration de la pop de départ est C0 = 0,1 , si la pop double la concentration devient 0,2 environ au bout de 3h30.

# %%
import numpy as np
import matplotlib.pyplot as plt

rmax = 0.4  # taux de croissance maximal (h⁻¹)
C0 = 0.1  # Concentration des cellules bactériennes au début de la simulation (10^3 cellules.mL-1)
T = 10 # durée totale de la simulation (heures)
dt = 0.1 # pas de temps (heures)
N_steps = int(T / dt)

time = np.linspace(0, T, N_steps)
C = C0 * np.exp(rmax * time)

plt.title('vitesse de croissance de la population globale en (10^3 cellules.mL-1.heure-1)')  # Titre du graphique
plt.plot(time, C, label='courbe 1') # Nom de la courbe
plt.xlabel('t(en h)') # Axe des X
plt.ylabel('C(10³cellules.mL-3)') # Axe des Y
plt.grid(True)
plt.legend()
plt.show()

import numpy as np
import matplotlib.pyplot as plt

rmax = 0.1  # taux de croissance maximal (h⁻¹)
C0 = 0.1  # Concentration des cellules bactériennes au début de la simulation (10^3 cellules.mL-1)
T = 10 # durée totale de la simulation (heures)
dt = 0.1 # pas de temps (heures)
N_steps = int(T / dt)

time = np.linspace(0, T, N_steps)
C = C0 * np.exp(rmax * time)

plt.title('vitesse de croissance de la population globale en (10^3 cellules.mL-1.heure-1)')  # Titre du graphique
plt.plot(time, C, label='courbe 1') # Nom de la courbe
plt.xlabel('t(en h)') # Axe des X
plt.ylabel('C(10³cellules.mL-3)') # Axe des Y
plt.grid(True)
plt.legend()
plt.show()

import numpy as np
import matplotlib.pyplot as plt

rmax = 0  # taux de croissance maximal (h⁻¹)
C0 = 0.1  # Concentration des cellules bactériennes au début de la simulation (10^3 cellules.mL-1)
T = 10 # durée totale de la simulation (heures)
dt = 0.1 # pas de temps (heures)
N_steps = int(T / dt)

time = np.linspace(0, T, N_steps)
C = C0 * np.exp(rmax * time)

plt.title('vitesse de croissance de la population globale en (10^3 cellules.mL-1.heure-1)')  # Titre du graphique
plt.plot(time, C, label='courbe 1') # Nom de la courbe
plt.xlabel('t(en h)') # Axe des X
plt.ylabel('C(10³cellules.mL-3)') # Axe des Y
plt.grid(True)
plt.legend()
plt.show()

import numpy as np
import matplotlib.pyplot as plt

rmax = -0.1  # taux de croissance maximal (h⁻¹)
C0 = 0.1  # Concentration des cellules bactériennes au début de la simulation (10^3 cellules.mL-1)
T = 10 # durée totale de la simulation (heures)
dt = 0.1 # pas de temps (heures)
N_steps = int(T / dt)

time = np.linspace(0, T, N_steps)
C = C0 * np.exp(rmax * time)

plt.title('vitesse de croissance de la population globale en (10^3 cellules.mL-1.heure-1)')  # Titre du graphique
plt.plot(time, C, label='courbe 1') # Nom de la courbe
plt.xlabel('t(en h)') # Axe des X
plt.ylabel('C(10³cellules.mL-3)') # Axe des Y
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# pour les 4 valeurs de rmax(= taux de croissance maximale de la population) on observe qu'une grande population produit plus de nouvelles cellules par unité de temps (par exemple durant 1 heure) qu’une petite population. Ainsi plus la population est grande et plus elle grandit vite.
# - pour rmax = 0,4 on observe une courbe exponentielle
# - pour rmax = 0,1 on observe une courbe qui croit plus mais plus lentement , ceci s'explique par le fait que la souche a une cycle de division limitée en fonction du temps , plus le cycle est rapide plus elle se divise vite, ici elle est plus lente
# - pour rmax = 0 on observe une ligne droite , constante dans le temps
# - pour rmax= -0,1 quand c'est négatif la courbe décroit. cela indique une décroissance cellulaire qui peut s'expliquer par une mort cellulaire ou un manque de ressource.
#
# Quelles sont les limites de ce modèle ? Que faudrait-il ajouter pour le rendre plus réaliste ?
# - le modèle ne prend pas en compte les ressources réellement disponibles dans le millieu. La bactérie connaitra une limite de division au moment ou les souches sont saturantes elle pourra pas aller au dela et se diviser plus .Le modèle de Malthus représente la croissance d’une souche bactérienne en conditions idéales, sans limitations de ressource.
# - le modèle de Monod est plus réaliste car il prend en compte la concentration du susbtrat énergétique .Donc il aurait fallut ajouter la cocnentration en substrat et l'affinité de la bactérie pour celui ci.de plus il prend en compte les morts cellulaire et permet de savoir et de connaitre la viabilité des cellules (C-mC)

# %%
import numpy as np
import matplotlib.pyplot as plt
# PARAMÈTRES DE LA SIMULATION
T = 300          # Durée totale (heures)
dt = 0.1          # Pas de temps (heures)
N_steps = int(T / dt)  # Nombre de pas de temps
# PARAMÈTRES DE LA SOUCHE
rmax = 0.10       # Taux de croissance maximal (h⁻¹)
K = 50           # Affinité pour le substrat (g/L)
m0 = 0.07         # Taux de mortalité minimal (h⁻¹)
C0 = 3 # Concentration initiale de bactéries (10³ cellules/mL)
# PARAMÈTRES DU SUBSTRAT (GLUCOSE)
initial_glucose = 400  # Concentration initiale de glucose (g/L)
glucose_inflow = 0      # Flux entrant de glucose (g/L/h)
# INITIALISATION DES TABLEAUX
C = np.zeros(N_steps)          # Concentration bactérienne
glucose_level = np.zeros(N_steps)
growth_rate = np.zeros(N_steps)
mortality_rate = np.zeros(N_steps)
# CONDITIONS INITIALES
C[0] = C0
glucose_level[0] = initial_glucose
growth_rate[0] = rmax * glucose_level[0] / (K + glucose_level[0])
mortality_rate[0] = m0
# SIMULATION
for i in range(1, N_steps):
    # Calcul des taux
    r = rmax * glucose_level[i-1] / (K + glucose_level[i-1])

    # Mise à jour de la population bactérienne
    C[i] = C[i-1] + dt * (r - m0) * C[i-1]
# Mise à jour du glucose (consommation + flux entrant)
    glucose_level[i] = glucose_level[i-1] - dt * r * C[i-1] + glucose_inflow * dt

    # Stockage des taux
    growth_rate[i] = r
    mortality_rate[i] = m0

# AXE DES X EN HEURES
time = np.linspace(0, T, N_steps)

# TRACÉ DES COURBES
plt.figure(figsize=(12, 8))

# 1. Concentration bactérienne
plt.subplot(4, 1, 1)
plt.plot(time, C, label='Nombre de bactéries', color='blue')
plt.title('Concentration des bactéries - Modèle de Monod')
plt.ylabel('10³ cellules/mL')
plt.grid(True)

# 2. Concentration de glucose
plt.subplot(4, 1, 2)
plt.plot(time, glucose_level, label='Concentration de glucose', color='green')
plt.title('Concentration de glucose')
plt.ylabel('g/L')
plt.grid(True)

# 3. Taux de croissance ET mortalité (sur le même graphique)
plt.subplot(4, 1, 3)
plt.plot(time, growth_rate, label='Taux de croissance (r)', color='red')
plt.plot(time, mortality_rate, label='Taux de mortalité (m)', color='black', linestyle='--')  # Ligne noire en pointillé
plt.title('Taux de croissance et de mortalité')
plt.ylabel('h⁻¹')
plt.legend()  # Affiche la légende pour les deux courbes
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# Questions :  Insérez les différents graphiques dans le document avec vos réponses.
#
# Décrirez l’évolution des différentes courbes.
# - courbe bleue (concentration des bactéries):on observe que la courbe augmente jusqu'a atteindre un pic àb170 à peu prés puis décroit
# - courbe verte (concentration de glucose) : on observe que la concentration est maximale puis diminue au cours du temps
# - courbe rouge : au début taux de mortalité nulle et taux de croissance maximale mais au cours du temps le taux de croissance diminue jusuqu'a atteindre un taux de croissanse quasi nulle.
# Quel est le facteur limitant dans cette expérience.
# - Les 3 courbes sont corrélés entre elles : au départ les bactéries ont des ressources et l'utilise et croit jusqua atteindre un pic , moment ou la concentration de glucose chute et que le taux de mortalité augmente .
# - le facteur limitant est le glucose, les ressources disponibles dans un milieu de culture sont généralement limitantes,la quantité de ressources n'est pas illimitée et les bactéries peuevent ne pas avoir accés a la quantité de nutriments néccessaire pour atteindre leur taux de croissance maximal rmax
# Pour quelles valeurs de r et m la population décroit ?
# -  r : Taux de croissance réel des bactéries (heure^-1)
# -  m: Taux mortalité des bactéries (heure-1)
# pour 0,07 a 170 heure^-1
# Faites varier les paramètre rmax, m0 et K
#
# Que faudrait-il pour que cette population se maintienne dans le temps ?
# - une ressource illimitée de glucose (qui entre continuellement)

# %%
import numpy as np
import matplotlib.pyplot as plt
# PARAMÈTRES DE LA SIMULATION
T = 2000          # Durée totale (heures)
dt = 0.1          # Pas de temps (heures)
N_steps = int(T / dt)  # Nombre de pas de temps
# PARAMÈTRES DE LA SOUCHE
rmax = 0.10       # Taux de croissance maximal (h⁻¹)
K = 50           # Affinité pour le substrat (g/L)
m0 = 0.07         # Taux de mortalité minimal (h⁻¹)
C0 = 10 # Concentration initiale de bactéries (10³ cellules/mL)
# PARAMÈTRES DU SUBSTRAT (GLUCOSE)
initial_glucose = 140  # Concentration initiale de glucose (g/L)
glucose_inflow = 3     # Flux entrant de glucose (g/L/h)
# INITIALISATION DES TABLEAUX
C = np.zeros(N_steps)          # Concentration bactérienne
glucose_level = np.zeros(N_steps)
growth_rate = np.zeros(N_steps)
mortality_rate = np.zeros(N_steps)
# CONDITIONS INITIALES
C[0] = C0
glucose_level[0] = initial_glucose
growth_rate[0] = rmax * glucose_level[0] / (K + glucose_level[0])
mortality_rate[0] = m0
# SIMULATION
for i in range(1, N_steps):
    # Calcul des taux
    r = rmax * glucose_level[i-1] / (K + glucose_level[i-1])

    # Mise à jour de la population bactérienne
    C[i] = C[i-1] + dt * (r - m0) * C[i-1]
# Mise à jour du glucose (consommation + flux entrant)
    glucose_level[i] = glucose_level[i-1] - dt * r * C[i-1] + glucose_inflow * dt

    # Stockage des taux
    growth_rate[i] = r
    mortality_rate[i] = m0

# AXE DES X EN HEURES
time = np.linspace(0, T, N_steps)

# TRACÉ DES COURBES
plt.figure(figsize=(12, 8))

# 1. Concentration bactérienne
plt.subplot(4, 1, 1)
plt.plot(time, C, label='Nombre de bactéries', color='blue')
plt.title('Concentration des bactéries - Modèle de Monod')
plt.ylabel('10³ cellules/mL')
plt.grid(True)

# 2. Concentration de glucose
plt.subplot(4, 1, 2)
plt.plot(time, glucose_level, label='Concentration de glucose', color='green')
plt.title('Concentration de glucose')
plt.ylabel('g/L')
plt.grid(True)

# 3. Taux de croissance ET mortalité (sur le même graphique)
plt.subplot(4, 1, 3)
plt.plot(time, growth_rate, label='Taux de croissance (r)', color='red')
plt.plot(time, mortality_rate, label='Taux de mortalité (m)', color='black', linestyle='--')  # Ligne noire en pointillé
plt.title('Taux de croissance et de mortalité')
plt.ylabel('h⁻¹')
plt.legend()  # Affiche la légende pour les deux courbes
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# - Décrivez les courbes
#  on observe dans les 3 courbes une fluctuation au début puis une stabilisation de celle ci a 1250H
# - Pourquoi la population bactérienne présente des fluctuations marquée avant de se stabiliser ?
# au départ le glucose est disponible , les bactéries l'utilise, il y'a des bactéries qui se divisent et d'autres qui meurent comme le flux est constant on atteint un équilibre car la source est disponible mais la division est limitée , quand r max est atteint meme si on ajoute des ressources la division ne peut pas aller au dela . en résumé on ajout du glucose elles l'utilisent , le glucose diminue , elles meurent , on en remet ainsi de suite jusqua saturation .
#  - Insérez différents graphiques dans le document et analysez-les

# %%
import numpy as np
import matplotlib.pyplot as plt
rmax_1 = 0.15      # Taux de croissance maximal (souche 1)
m0_1 = 0.06      # Taux de mortalité de base (souche 1)
K_1 = 800        # Constante de demi-saturation (souche 1)
rmax_2 = 0.15      # Taux de croissance maximal (souche 2)
m0_2 = 0.06      # Taux de mortalité de base (souche 2)
K_2 = 650      # Constante de demi-saturation (souche 2) - affinité plus élevée pour le glucose
initial_glucose = 1200   # Quantité initiale de glucose
glucose_inflow = 4      # Flux entrant de glucose (0 = système fermé)
C0_1 = 10  # Concentration initiale de la souche 1
C0_2 = 10   # Concentration initiale de la souche 2
dt = 0.1         # Pas de temps
T = 2000         # Durée totale de la simulation
N_steps = int(T / dt)# Nombre de pas de temps
C1 = np.zeros(N_steps)
C2 = np.zeros(N_steps)
glucose_level = np.zeros(N_steps)
growth_rate_1 = np.zeros(N_steps)
growth_rate_2 = np.zeros(N_steps)
mortality_rate_1 = np.zeros(N_steps)
mortality_rate_2 = np.zeros(N_steps)
C1[0] = C0_1
C2[0] = C0_2
glucose_level[0] = initial_glucose
growth_rate_1[0] = rmax_1 * glucose_level[0] / (K_1 + glucose_level[0])
growth_rate_2[0] = rmax_2 * glucose_level[0] / (K_2 + glucose_level[0])
mortality_rate_1[0] = m0_1
mortality_rate_2[0] = m0_2
for i in range(1, N_steps):
    # Calcul des taux de croissance pour chaque souche (modèle de Monod)
    r_1 = rmax_1 * glucose_level[i-1] / (K_1 + glucose_level[i-1])
    r_2 = rmax_2 * glucose_level[i-1] / (K_2 + glucose_level[i-1])

    # Mortalité variable (augmente si le glucose est faible)
    #m_1 = m0_1 + 0.01 * (1 - glucose_level[i-1] / initial_glucose)
    #m_2 = m0_2 + 0.01 * (1 - glucose_level[i-1] / initial_glucose)

      # Mortalité constante
    m_1 = m0_1 
    m_2 = m0_2
    
    # Mise à jour des populations bactériennes
    C1[i] = C1[i-1] + dt * (r_1 - m_1) * C1[i-1]
    C2[i] = C2[i-1] + dt * (r_2 - m_2) * C2[i-1]

    # Consommation totale de glucose (somme des consommations des deux souches)
    glucose_consumption = (r_1 * C1[i-1] + r_2 * C2[i-1])
    glucose_level[i] = glucose_level[i-1] - dt * glucose_consumption + glucose_inflow * dt

    # Stockage des taux
    growth_rate_1[i] = r_1
    growth_rate_2[i] = r_2
    mortality_rate_1[i] = m_1
    mortality_rate_2[i] = m_2

# Temps pour l'axe des abscisses

time = np.linspace(0, T, N_steps)
# Tracé des courbes
plt.figure(figsize=(12, 12))

# Population des bactéries
plt.subplot(4, 1, 1)
plt.plot(time, C1, label='Souche 1', color='blue')
plt.plot(time, C2, label='Souche 2', color='orange')
plt.title('Compétition entre 2 souches - Modèle de Monod')
plt.ylabel('10³ cellules/mL')
plt.legend()
plt.grid(True)

# Niveau de glucose
plt.subplot(4, 1, 2)
plt.plot(time, glucose_level, label='Glucose', color='green')
plt.title('Concentration de glucose')
plt.ylabel('g/L')
plt.grid(True)

# Taux de croissance et mortalité
plt.subplot(4, 1, 3)
plt.plot(time, growth_rate_1, label='Taux de croissance (Souche 1)', color='blue', linestyle='--')
plt.plot(time, growth_rate_2, label='Taux de croissance (Souche 2)', color='orange', linestyle='--')
plt.plot(time, mortality_rate_1, label='Taux de mortalité (Souche 1)', color='blue', linestyle=':')
plt.plot(time, mortality_rate_2, label='Taux de mortalité (Souche 2)', color='orange', linestyle=':')
plt.title('Taux de croissance (r) et de mortalité (m)')
plt.ylabel('h⁻¹')
plt.legend()
plt.grid(True)

# Taux de mortalité
#plt.subplot(4, 1, 4)
#plt.plot(time, mortality_rate_1, label='Taux de mortalité (Souche 1)', color='blue', linestyle=':')
#plt.plot(time, mortality_rate_2, label='Taux de mortalité (Souche 2)', color='orange', linestyle=':')
#plt.title('Taux de mortalité (m) au fil du temps')
#plt.xlabel('Temps')
#plt.ylabel('Taux de mortalité (m)')
#plt.legend()
#plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
#
#  Décrivez les courbes.
#
# Le paramètre qui change pour la socuhe 1 et 2 est K :
# - K_1 = 800        # Constante de demi-saturation (souche 1)
# - K_2 = 650        # Constante de demi-saturation (souche 2) la souche 2 a  une affinité plus élevée pour le glucose. Un  faible K signifie que les bactéries ont une forte affinité pour le substrat (elles peuvent croître efficacement même à de faibles concentrations de substrat).
# la souche 2 = courbe jaune exploite les ressources mieux que la souche 1 avec une concentration de glucose identique pour les 2 souches. sont taux de croissance est plus élevée
#
#
#  Quel est le résultat de la concurrence sur le devenir des populations ?
# - la souche 2 va dominer la 1 en terme de division et de taux de croissance car son affinité est plus elevée pour le substrat .
# Le paramètre qui change pour la socuhe 1 et 2 est K :
# - K_1 = 800        # Constante de demi-saturation (souche 1)
# - K_2 = 650        # Constante de demi-saturation (souche 2) la souche 2 a  une affinité plus élevée pour le glucose. Un  faible K signifie que les bactéries ont une forte affinité pour le substrat (elles peuvent croître efficacement même à de faibles concentrations de substrat).

# %%
import numpy as np
import matplotlib.pyplot as plt
rmax_1 = 0.15      # Taux de croissance maximal (souche 1)
m0_1 = 0.05  # Taux de mortalité de base (souche 1)
K_1 = 800        # Constante de demi-saturation (souche 1)
rmax_2 = 0.15      # Taux de croissance maximal (souche 2)
m0_2 = 0.06      # Taux de mortalité de base (souche 2)
K_2 = 650      # Constante de demi-saturation (souche 2) - affinité plus élevée pour le glucose
initial_glucose = 1200   # Quantité initiale de glucose
glucose_inflow = 4      # Flux entrant de glucose (0 = système fermé)
C0_1 = 10  # Concentration initiale de la souche 1
C0_2 = 10   # Concentration initiale de la souche 2
dt = 0.1         # Pas de temps
T = 2000         # Durée totale de la simulation
N_steps = int(T / dt)# Nombre de pas de temps
C1 = np.zeros(N_steps)
C2 = np.zeros(N_steps)
glucose_level = np.zeros(N_steps)
growth_rate_1 = np.zeros(N_steps)
growth_rate_2 = np.zeros(N_steps)
mortality_rate_1 = np.zeros(N_steps)
mortality_rate_2 = np.zeros(N_steps)
C1[0] = C0_1
C2[0] = C0_2
glucose_level[0] = initial_glucose
growth_rate_1[0] = rmax_1 * glucose_level[0] / (K_1 + glucose_level[0])
growth_rate_2[0] = rmax_2 * glucose_level[0] / (K_2 + glucose_level[0])
mortality_rate_1[0] = m0_1
mortality_rate_2[0] = m0_2
for i in range(1, N_steps):
    # Calcul des taux de croissance pour chaque souche (modèle de Monod)
    r_1 = rmax_1 * glucose_level[i-1] / (K_1 + glucose_level[i-1])
    r_2 = rmax_2 * glucose_level[i-1] / (K_2 + glucose_level[i-1])

    # Mortalité variable (augmente si le glucose est faible)
    #m_1 = m0_1 + 0.01 * (1 - glucose_level[i-1] / initial_glucose)
    #m_2 = m0_2 + 0.01 * (1 - glucose_level[i-1] / initial_glucose)

      # Mortalité constante
    m_1 = m0_1 
    m_2 = m0_2
    
    # Mise à jour des populations bactériennes
    C1[i] = C1[i-1] + dt * (r_1 - m_1) * C1[i-1]
    C2[i] = C2[i-1] + dt * (r_2 - m_2) * C2[i-1]

    # Consommation totale de glucose (somme des consommations des deux souches)
    glucose_consumption = (r_1 * C1[i-1] + r_2 * C2[i-1])
    glucose_level[i] = glucose_level[i-1] - dt * glucose_consumption + glucose_inflow * dt

    # Stockage des taux
    growth_rate_1[i] = r_1
    growth_rate_2[i] = r_2
    mortality_rate_1[i] = m_1
    mortality_rate_2[i] = m_2

# Temps pour l'axe des abscisses

time = np.linspace(0, T, N_steps)
# Tracé des courbes
plt.figure(figsize=(12, 12))

# Population des bactéries
plt.subplot(4, 1, 1)
plt.plot(time, C1, label='Souche 1', color='blue')
plt.plot(time, C2, label='Souche 2', color='orange')
plt.title('Compétition entre 2 souches - Modèle de Monod')
plt.ylabel('10³ cellules/mL')
plt.legend()
plt.grid(True)

# Niveau de glucose
plt.subplot(4, 1, 2)
plt.plot(time, glucose_level, label='Glucose', color='green')
plt.title('Concentration de glucose')
plt.ylabel('g/L')
plt.grid(True)

# Taux de croissance et mortalité
plt.subplot(4, 1, 3)
plt.plot(time, growth_rate_1, label='Taux de croissance (Souche 1)', color='blue', linestyle='--')
plt.plot(time, growth_rate_2, label='Taux de croissance (Souche 2)', color='orange', linestyle='--')
plt.plot(time, mortality_rate_1, label='Taux de mortalité (Souche 1)', color='blue', linestyle=':')
plt.plot(time, mortality_rate_2, label='Taux de mortalité (Souche 2)', color='orange', linestyle=':')
plt.title('Taux de croissance (r) et de mortalité (m)')
plt.ylabel('h⁻¹')
plt.legend()
plt.grid(True)

# Taux de mortalité
#plt.subplot(4, 1, 4)
#plt.plot(time, mortality_rate_1, label='Taux de mortalité (Souche 1)', color='blue', linestyle=':')
#plt.plot(time, mortality_rate_2, label='Taux de mortalité (Souche 2)', color='orange', linestyle=':')
#plt.title('Taux de mortalité (m) au fil du temps')
#plt.xlabel('Temps')
#plt.ylabel('Taux de mortalité (m)')
#plt.legend()
#plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# Modifiez le paramètre m de la souche 1. A partir de quelle valeur celle-ci l’emporte sur la souche 2 ?
# a partir de 0,04
