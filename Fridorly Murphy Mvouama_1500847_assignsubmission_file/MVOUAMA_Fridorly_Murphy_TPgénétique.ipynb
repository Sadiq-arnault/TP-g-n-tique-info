# %% [markdown]
# MVOUAMA Fridorly Murphy
# 12513844

# %%
import numpy as np
import matplotlib.pyplot as plt

# Paramètres de la simulation
rmax = 0.2  # taux de croissance maximal (h⁻¹)
C0 = 0.1  # Concentration des cellules bactériennes au début de la simulation (10^3 cellules.mL-1)
T = 10 # durée totale de la simulation (heures)
dt = 0.1 # pas de temps (heures)
N_steps = int(T / dt)

# Simulation
time = np.linspace(0, T, N_steps)
C = C0 * np.exp(rmax * time)

# Tracé du graphique
plt.title('Croissance bactérienne')  # Titre du graphique
plt.plot(time, C, label='Concentration bactérienne') # Nom de la courbe
plt.xlabel('temps heure') # Axe des X
plt.ylabel('Concentration bactériennes 103 cellules.mL-1') # Axe des Y
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# .ce type de courbe est appelée: Courbe exponentielle
# .La population double en environ de 3.5 heures

# %% [markdown]
# La population double en environ de 3.5 heures

# %%
import numpy as np
import matplotlib.pyplot as plt

# Paramètres de la simulation
rmax = 0.4  # taux de croissance maximal (h⁻¹)
C0 = 0.1  # Concentration des cellules bactériennes au début de la simulation (10^3 cellules.mL-1)
T = 10 # durée totale de la simulation (heures)
dt = 0.1 # pas de temps (heures)
N_steps = int(T / dt)

# Simulation
time = np.linspace(0, T, N_steps)
C = C0 * np.exp(rmax * time)

# Tracé du graphique
plt.title('Croissance bactérienne')  # Titre du graphique
plt.plot(time, C, label='Concentration bactérienne') # Nom de la courbe
plt.xlabel('temps heure') # Axe des X
plt.ylabel('Concentration bactériennes 103 cellules.mL-1') # Axe des Y
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# croissance rapide , la courbe monte fortement

# %%
import numpy as np
import matplotlib.pyplot as plt

# Paramètres de la simulation
rmax = 0.1  # taux de croissance maximal (h⁻¹)
C0 = 0.1  # Concentration des cellules bactériennes au début de la simulation (10^3 cellules.mL-1)
T = 10 # durée totale de la simulation (heures)
dt = 0.1 # pas de temps (heures)
N_steps = int(T / dt)

# Simulation
time = np.linspace(0, T, N_steps)
C = C0 * np.exp(rmax * time)

# Tracé du graphique
plt.title('Croissance bactérienne')  # Titre du graphique
plt.plot(time, C, label='Concentration bactérienne') # Nom de la courbe
plt.xlabel('temps heure') # Axe des X
plt.ylabel('Concentration bactériennes 103 cellules.mL-1') # Axe des Y
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# Croissance plus lente, la population augmente progressivement

# %%
import numpy as np
import matplotlib.pyplot as plt

# Paramètres de la simulation
rmax = 0.0  # taux de croissance maximal (h⁻¹)
C0 = 0.1  # Concentration des cellules bactériennes au début de la simulation (10^3 cellules.mL-1)
T = 10 # durée totale de la simulation (heures)
dt = 0.1 # pas de temps (heures)
N_steps = int(T / dt)

# Simulation
time = np.linspace(0, T, N_steps)
C = C0 * np.exp(rmax * time)

# Tracé du graphique
plt.title('Croissance bactérienne')  # Titre du graphique
plt.plot(time, C, label='Concentration bactérienne') # Nom de la courbe
plt.xlabel('temps heure') # Axe des X
plt.ylabel('Concentration bactériennes 103 cellules.mL-1') # Axe des Y
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# La croissance reste constante

# %%
import numpy as np
import matplotlib.pyplot as plt

# Paramètres de la simulation
rmax = -0.1  # taux de croissance maximal (h⁻¹)
C0 = 0.1  # Concentration des cellules bactériennes au début de la simulation (10^3 cellules.mL-1)
T = 10 # durée totale de la simulation (heures)
dt = 0.1 # pas de temps (heures)
N_steps = int(T / dt)

# Simulation
time = np.linspace(0, T, N_steps)
C = C0 * np.exp(rmax * time)

# Tracé du graphique
plt.title('Croissance bactérienne')  # Titre du graphique
plt.plot(time, C, label='Concentration bactérienne') # Nom de la courbe
plt.xlabel('temps heure') # Axe des X
plt.ylabel('Concentration bactériennes 103 cellules.mL-1') # Axe des Y
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# Décroissance exponentielle, les bactéries disparaissent progressivement

# %% [markdown]
# Les limites de ce modèle sont:
#  -Réssources illimitées
#  -Espace illimité
#  -Aucune compétition
#  -Environnement constant

# %% [markdown]
# Pour le rendre réaliste il faudrait ajouter:
#     -une capacité maximale du milieu
#     -une limitation des nutriments
#     -compétition entre bactéries
#     -la mortalité

# %%
import numpy as np
import matplotlib.pyplot as plt

# ======================
# PARAMÈTRES DE LA SIMULATION
# ======================
T = 300          # Durée totale (heures)
dt = 0.1          # Pas de temps (heures)
N_steps = int(T / dt)  # Nombre de pas de temps

# ======================
# PARAMÈTRES DE LA SOUCHE
# ======================
rmax = 0.10       # Taux de croissance maximal (h⁻¹)
K = 50           # Affinité pour le substrat (g/L)
m0 = 0.07         # Taux de mortalité minimal (h⁻¹)
C0 = 3 # Concentration initiale de bactéries (10³ cellules/mL)

# ======================
# PARAMÈTRES DU SUBSTRAT (GLUCOSE)
# ======================
initial_glucose = 400  # Concentration initiale de glucose (g/L)
glucose_inflow = 0      # Flux entrant de glucose (g/L/h)

# ======================
# INITIALISATION DES TABLEAUX
# ======================
C = np.zeros(N_steps)          # Concentration bactérienne
glucose_level = np.zeros(N_steps)
growth_rate = np.zeros(N_steps)
mortality_rate = np.zeros(N_steps)

# ======================
# CONDITIONS INITIALES
# ======================
C[0] = C0
glucose_level[0] = initial_glucose
growth_rate[0] = rmax * glucose_level[0] / (K + glucose_level[0])
mortality_rate[0] = m0

# ======================
# SIMULATION
# ======================
for i in range(1, N_steps):
    # Calcul des taux
    r = rmax * glucose_level[i-1] / (K + glucose_level[i-1])

    # Mise à jour de la population bactérienne
    C[i] = C[i-1] + dt * (r - m0) * C[i-1]

    # Mise à jour du glucose (consommation + flux entrant)
    glucose_level[i] = glucose_level[i-1] - dt * r * C[i-1] + glucose_inflow * dt

    # Stockage des taux
    growth_rate[i] = r
    mortality_rate[i] = m0

# ======================
# AXE DES X EN HEURES
# ======================
time = np.linspace(0, T, N_steps)

# ======================
# TRACÉ DES COURBES
# ======================
plt.figure(figsize=(12, 8))

# 1. Concentration bactérienne
plt.subplot(4, 1, 1)
plt.plot(time, C, label='Nombre de bactéries', color='blue')
plt.title('Concentration des bactéries - Modèle de Monod')
plt.ylabel('10³ cellules/mL')
plt.grid(True)

# 2. Concentration de glucose
plt.subplot(4, 1, 2)
plt.plot(time, glucose_level, label='Concentration de glucose', color='green')
plt.title('Concentration de glucose')
plt.ylabel('g/L')
plt.grid(True)

# 3. Taux de croissance ET mortalité (sur le même graphique)
plt.subplot(4, 1, 3)
plt.plot(time, growth_rate, label='Taux de croissance (r)', color='red')
plt.plot(time, mortality_rate, label='Taux de mortalité (m)', color='black', linestyle='--')  # Ligne noire en pointillé
plt.title('Taux de croissance et de mortalité')
plt.ylabel('h⁻¹')
plt.legend()  # Affiche la légende pour les deux courbes
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# Description de l'évolution des différentes courbes:
# La forte concentration du glucose entraine le taux de croissance proche de rmax , la population bactérienne augmente.
# Ensuite, le glucose est consommé,sa concentration diminue. La baisse du glucose entraine une diminution du taux de
# croissance(r diminue).Quand le taux de croissance devient proche du taux de mortalité, la croissance ralentie

# %% [markdown]
# La concentration bactérienne:évolue en fonction du taux de croissance(r-m0)

# %% [markdown]
# La concentration du glucose:diminue par consommation bactérienne, avec un éventuel apport externe

# %% [markdown]
# Taux de croissance (r): dépendant de la concentration du glucose selon la relation de Monod

# %% [markdown]
# Taux de mortalité (m0): un taux constant dans ce modèle

# %% [markdown]
# Quel est le facteur limitant dans cette expérience:
# Le facteur limitant est la concentration en glucose, qui est le substrat essentiel à la croissance bacterienne

# %% [markdown]
# Pour quelles valeurs de r et m la population décroit ?
# La population bactérienne decroît lorsque le taux de croissance est négatif:(r-m0)<0
