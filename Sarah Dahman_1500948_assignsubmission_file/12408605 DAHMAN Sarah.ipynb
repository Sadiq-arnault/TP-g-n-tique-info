# %% [markdown]
# Dahman Sarah 12408605

# %%
import numpy as np
import matplotlib.pyplot as plt

rmax = 0.2
C0 = 0.1
T = 10
dt = 0.1
N_steps = int(T / dt)
time = np.linspace(0, T, N_steps)
C = C0 * np.exp(rmax * time)
plt.title('Courbe de la croissance bacterienne dunne population bacterienne en fonction du temps') 
plt.plot(time, C, label= 'vitesse de croissance de la population bacterienne')
plt.xlabel('temps(heure-1)')
plt.ylabel('concentration des cellules bacterienne (cellules.mL-1))') 
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# Ce type de courbe correspond à une exponentielle
# La population double en environ 3h30

# %%
import numpy as np
import matplotlib.pyplot as plt

rmax = 0.4
C0 = 0.1
T = 10
dt = 0.1
N_steps = int(T / dt)
time = np.linspace(0, T, N_steps)
C = C0 * np.exp(rmax * time)
plt.title('Courbe de la croissance bacterienne dunne population bacterienne en fonction du temps') 
plt.plot(time, C, label= 'vitesse de croissance de la population bacterienne')
plt.xlabel('temps(heure-1)')
plt.ylabel('concentration des cellules bacterienne (cellules.mL-1))') 
plt.grid(True)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

rmax = 0.1
C0 = 0.1
T = 10
dt = 0.1
N_steps = int(T / dt)
time = np.linspace(0, T, N_steps)
C = C0 * np.exp(rmax * time)
plt.title('Courbe de la croissance bacterienne dunne population bacterienne en fonction du temps') 
plt.plot(time, C, label= 'vitesse de croissance de la population bacterienne')
plt.xlabel('temps(heure-1)')
plt.ylabel('concentration des cellules bacterienne (cellules.mL-1))') 
plt.grid(True)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

rmax = 0
C0 = 0.1
T = 10
dt = 0.1
N_steps = int(T / dt)
time = np.linspace(0, T, N_steps)
C = C0 * np.exp(rmax * time)
plt.title('Courbe de la croissance bacterienne dunne population bacterienne en fonction du temps') 
plt.plot(time, C, label= 'vitesse de croissance de la population bacterienne')
plt.xlabel('temps(heure-1)')
plt.ylabel('concentration des cellules bacterienne (cellules.mL-1))') 
plt.grid(True)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

rmax = -0.1
C0 = 0.1
T = 10
dt = 0.1
N_steps = int(T / dt)
time = np.linspace(0, T, N_steps)
C = C0 * np.exp(rmax * time)
plt.title('Courbe de la croissance bacterienne dunne population bacterienne en fonction du temps') 
plt.plot(time, C, label= 'vitesse de croissance de la population bacterienne')
plt.xlabel('temps(heure-1)')
plt.ylabel('concentration des cellules bacterienne (cellules.mL-1))') 
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# r = 0.4 La croissance est très rapide. la courbe exponentielle monte fortement
# r = 0.1 La croisssance existe toujours mais reste plus lente
# r = 0 La population reste constante. le nombre de bactéries ne change pas
# r= -0.1 La population diminue progressivement. Il y a plus de mortalité que de divisions cellulaires

# %% [markdown]
# Ce modèle a bien des limites, il ne corresponds pas à la réalité. Les ressources sont considérés comme infinie, il n'y a pas de compétition ni de mortalité.
# Pour le rendre plus réaliste il faudrait ajouter une limitation de croissance, un taux de mortalité et une compétition entre les bactéries.

# %%
import numpy as np
import matplotlib.pyplot as plt

T = 300
dt = 0.1
N_steps = int(T / dt)

rmax = 0.10
K = 50 
m0 = 0.07
C0 = 3

initial_glucose = 400
glucose_inflow = 0 

C = np.zeros(N_steps) 
glucose_level = np.zeros(N_steps)
growth_rate = np.zeros(N_steps)
mortality_rate = np.zeros(N_steps)

C[0] = C0
glucose_level[0] = initial_glucose
growth_rate[0] = rmax * glucose_level[0] / (K + glucose_level[0])
mortality_rate[0] = m0

for i in range(1, N_steps):
    r = rmax * glucose_level[i-1] / (K + glucose_level[i-1])
    C[i] = C[i-1] + dt * (r - m0) * C[i-1]
    glucose_level[i] = glucose_level[i-1] - dt * r * C[i-1] + glucose_inflow * dt
    growth_rate[i] = r
    mortality_rate[i] = m0

time = np.linspace(0, T, N_steps)
plt.figure(figsize=(12, 8))

plt.subplot(4, 1, 1)
plt.plot(time, C, label='Nombre de bactéries', color='blue')
plt.title('Concentration des bactéries - Modèle de Monod')
plt.ylabel('10³ cellules/mL')
plt.grid(True)

plt.subplot(4, 1, 2)
plt.plot(time, glucose_level, label='Concentration de glucose', color='green')
plt.title('Concentration de glucose')
plt.ylabel('g/L')
plt.grid(True)

plt.subplot(4, 1, 3)
plt.plot(time, growth_rate, label='Taux de croissance (r)', color='red')
plt.plot(time, mortality_rate, label='Taux de mortalité (m)', color='black', linestyle='--') # Ligne noire en pointillé
plt.title('Taux de croissance et de mortalité')
plt.ylabel('h⁻¹')
plt.legend() 
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# Au début la population augmente puis le glucose diminue puis la croissance ralentit. Finalement la population peut diminuer si la mortilité devient supérieure à la croissance. Le taux de mortalité reste constant

# %% [markdown]
# Le facteur limitant est le GLUCOSE

# %% [markdown]
# La populations décroit lorsque r<m la mortalité devient alors supérieure à la croissance

# %% [markdown]
# Plus rmax est élevé plus la croissance est rapide.
# Plus m0 est élevé, plus il y a une diminution de la population.
# Si K est petit, il y a une meilleure affinité au glucose.
# Si K est grand, il y a croissance plus difficile lorsque le glucose est faible.

# %% [markdown]
# Il faudrait un apport continu en glucose, une croissance suffisante, une mortalité faible

# %%
import numpy as np
import matplotlib.pyplot as plt

T = 2000
dt = 0.1
N_steps = int(T / dt)

rmax = 0.10
K = 50 
m0 = 0.07
C0 = 10

initial_glucose = 140
glucose_inflow = 3

C = np.zeros(N_steps) 
glucose_level = np.zeros(N_steps)
growth_rate = np.zeros(N_steps)
mortality_rate = np.zeros(N_steps)

C[0] = C0
glucose_level[0] = initial_glucose
growth_rate[0] = rmax * glucose_level[0] / (K + glucose_level[0])
mortality_rate[0] = m0

for i in range(1, N_steps):
    r = rmax * glucose_level[i-1] / (K + glucose_level[i-1])
    C[i] = C[i-1] + dt * (r - m0) * C[i-1]
    glucose_level[i] = glucose_level[i-1] - dt * r * C[i-1] + glucose_inflow * dt
    growth_rate[i] = r
    mortality_rate[i] = m0

time = np.linspace(0, T, N_steps)
plt.figure(figsize=(12, 8))

plt.subplot(4, 1, 1)
plt.plot(time, C, label='Nombre de bactéries', color='blue')
plt.title('Concentration des bactéries - Modèle de Monod')
plt.ylabel('10³ cellules/mL')
plt.grid(True)

plt.subplot(4, 1, 2)
plt.plot(time, glucose_level, label='Concentration de glucose', color='green')
plt.title('Concentration de glucose')
plt.ylabel('g/L')
plt.grid(True)

plt.subplot(4, 1, 3)
plt.plot(time, growth_rate, label='Taux de croissance (r)', color='red')
plt.plot(time, mortality_rate, label='Taux de mortalité (m)', color='black', linestyle='--') # Ligne noire en pointillé
plt.title('Taux de croissance et de mortalité')
plt.ylabel('h⁻¹')
plt.legend() 
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# Au début, la population augmente rapidemenet le glucose diminue fortement.
#
# Ensuite, la glucose apporté permet à la population de survivre, des oscillations apparaissent, la population finit par se stabiliser autour d'un équilibre

# %% [markdown]
# Les bactéries consomment le gllucose plus vite qu'il n'arrive:
#     Le glucose baisse;
#     la croissance ralentit;
#     la population diminiue;
#     le glucose remonte;
#     la croissance repart.

# %%
import numpy as np
import matplotlib.pyplot as plt

rmax_1 = 0.15 
m0_1 = 0.06
K_1 = 800

rmax_2 = 0.15
m0_2 = 0.06
K_2 = 650

initial_glucose = 1200
glucose_inflow = 4

C0_1 = 10
C0_2 = 10
dt = 0.1
T = 2000
N_steps = int(T / dt)

C1 = np.zeros(N_steps)
C2 = np.zeros(N_steps)
glucose_level = np.zeros(N_steps)
growth_rate_1 = np.zeros(N_steps)
growth_rate_2 = np.zeros(N_steps)
mortality_rate_1 = np.zeros(N_steps)
mortality_rate_2 = np.zeros(N_steps)

C1[0] = C0_1
C2[0] = C0_2
glucose_level[0] = initial_glucose
growth_rate_1[0] = rmax_1 * glucose_level[0] / (K_1 + glucose_level[0])
growth_rate_2[0] = rmax_2 * glucose_level[0] / (K_2 + glucose_level[0])
mortality_rate_1[0] = m0_1
mortality_rate_2[0] = m0_2

for i in range(1, N_steps):
    r_1 = rmax_1 * glucose_level[i-1] / (K_1 + glucose_level[i-1])
    r_2 = rmax_2 * glucose_level[i-1] / (K_2 + glucose_level[i-1])
    
    m_1 = m0_1 + 0.01 * (1 - glucose_level[i-1] / initial_glucose)
    m_2 = m0_2 + 0.01 * (1 - glucose_level[i-1] / initial_glucose)
    
    m_1 = m0_1
    m_2 = m0_2
    
    C1[i] = C1[i-1] + dt * (r_1 - m_1) * C1[i-1]
    C2[i] = C2[i-1] + dt * (r_2 - m_2) * C2[i-1]
    
    glucose_consumption = (r_1 * C1[i-1] + r_2 * C2[i-1])
    glucose_level[i] = glucose_level[i-1] - dt * glucose_consumption + glucose_inflow * dt
    
    growth_rate_1[i] = r_1
    growth_rate_2[i] = r_2
    mortality_rate_1[i] = m_1
    mortality_rate_2[i] = m_2
    
time = np.linspace(0, T, N_steps)
plt.figure(figsize=(12, 12))

plt.subplot(4, 1, 1)
plt.plot(time, C1, label='Souche 1', color='blue')
plt.plot(time, C2, label='Souche 2', color='orange')
plt.title('Compétition entre 2 souches - Modèle de Monod')
plt.ylabel('10³ cellules/mL')
plt.legend()
plt.grid(True)

plt.subplot(4, 1, 2)
plt.plot(time, glucose_level, label='Glucose', color='green')
plt.title('Concentration de glucose')
plt.ylabel('g/L')
plt.grid(True)

plt.subplot(4, 1, 3)
plt.plot(time, growth_rate_1, label='Taux de croissance (Souche 1)', color='blue', linestyle='--')
plt.plot(time, growth_rate_2, label='Taux de croissance (Souche 2)', color='orange', linestyle='--')
plt.plot(time, mortality_rate_1, label='Taux de mortalité (Souche 1)', color='blue', linestyle=':')
plt.plot(time, mortality_rate_2, label='Taux de mortalité (Souche 2)', color='orange', linestyle=':')
plt.title('Taux de croissance (r) et de mortalité (m)')
plt.ylabel('h⁻¹')
plt.legend()
plt.grid(True)

plt.subplot(4, 1, 4)
plt.plot(time, mortality_rate_1, label='Taux de mortalité (Souche 1)', color='blue', linestyle=':')
plt.plot(time, mortality_rate_2, label='Taux de mortalité (Souche 2)', color='orange', linestyle=':')
plt.title('Taux de mortalité (m) au fil du temps')
plt.xlabel('Temps')
plt.ylabel('Taux de mortalité (m)')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# Au début, les deux souches se développent au début. Mais la souche 2 possède un meilleur K; elle utilise le glucose plus efficacement, ellefinit par dominer la souche 1 .

# %% [markdown]
# La souche la mieux adabtée consomme davantage de ressources, prend l'avantage, peut conduir à la disparition de l'autre souche
# C'est un exemple de SELECTION NATURELLE

# %%
import numpy as np
import matplotlib.pyplot as plt

rmax_1 = 0.15 
m0_1 = 0.0525
K_1 = 800

rmax_2 = 0.15
m0_2 = 0.06
K_2 = 650

initial_glucose = 1200
glucose_inflow = 4

C0_1 = 10
C0_2 = 10
dt = 0.1
T = 2000
N_steps = int(T / dt)

C1 = np.zeros(N_steps)
C2 = np.zeros(N_steps)
glucose_level = np.zeros(N_steps)
growth_rate_1 = np.zeros(N_steps)
growth_rate_2 = np.zeros(N_steps)
mortality_rate_1 = np.zeros(N_steps)
mortality_rate_2 = np.zeros(N_steps)

C1[0] = C0_1
C2[0] = C0_2
glucose_level[0] = initial_glucose
growth_rate_1[0] = rmax_1 * glucose_level[0] / (K_1 + glucose_level[0])
growth_rate_2[0] = rmax_2 * glucose_level[0] / (K_2 + glucose_level[0])
mortality_rate_1[0] = m0_1
mortality_rate_2[0] = m0_2

for i in range(1, N_steps):
    r_1 = rmax_1 * glucose_level[i-1] / (K_1 + glucose_level[i-1])
    r_2 = rmax_2 * glucose_level[i-1] / (K_2 + glucose_level[i-1])
    
    m_1 = m0_1 + 0.01 * (1 - glucose_level[i-1] / initial_glucose)
    m_2 = m0_2 + 0.01 * (1 - glucose_level[i-1] / initial_glucose)
    
    m_1 = m0_1
    m_2 = m0_2
    
    C1[i] = C1[i-1] + dt * (r_1 - m_1) * C1[i-1]
    C2[i] = C2[i-1] + dt * (r_2 - m_2) * C2[i-1]
    
    glucose_consumption = (r_1 * C1[i-1] + r_2 * C2[i-1])
    glucose_level[i] = glucose_level[i-1] - dt * glucose_consumption + glucose_inflow * dt
    
    growth_rate_1[i] = r_1
    growth_rate_2[i] = r_2
    mortality_rate_1[i] = m_1
    mortality_rate_2[i] = m_2
    
time = np.linspace(0, T, N_steps)
plt.figure(figsize=(12, 12))

plt.subplot(4, 1, 1)
plt.plot(time, C1, label='Souche 1', color='blue')
plt.plot(time, C2, label='Souche 2', color='orange')
plt.title('Compétition entre 2 souches - Modèle de Monod')
plt.ylabel('10³ cellules/mL')
plt.legend()
plt.grid(True)

plt.subplot(4, 1, 2)
plt.plot(time, glucose_level, label='Glucose', color='green')
plt.title('Concentration de glucose')
plt.ylabel('g/L')
plt.grid(True)

plt.subplot(4, 1, 3)
plt.plot(time, growth_rate_1, label='Taux de croissance (Souche 1)', color='blue', linestyle='--')
plt.plot(time, growth_rate_2, label='Taux de croissance (Souche 2)', color='orange', linestyle='--')
plt.plot(time, mortality_rate_1, label='Taux de mortalité (Souche 1)', color='blue', linestyle=':')
plt.plot(time, mortality_rate_2, label='Taux de mortalité (Souche 2)', color='orange', linestyle=':')
plt.title('Taux de croissance (r) et de mortalité (m)')
plt.ylabel('h⁻¹')
plt.legend()
plt.grid(True)

plt.subplot(4, 1, 4)
plt.plot(time, mortality_rate_1, label='Taux de mortalité (Souche 1)', color='blue', linestyle=':')
plt.plot(time, mortality_rate_2, label='Taux de mortalité (Souche 2)', color='orange', linestyle=':')
plt.title('Taux de mortalité (m) au fil du temps')
plt.xlabel('Temps')
plt.ylabel('Taux de mortalité (m)')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# A partir de m01= 0.0525, la souche 1 l'emporte sur la souche 2

# %%
import numpy as np
import matplotlib.pyplot as plt

rmax_1 = 0.15 
m0_1 = 0.07
K_1 = 800
resistance_1 = 0 

rmax_2 = 0.15 
m0_2 = 0.07 
K_2 = 650 
resistance_2 = 0 

initial_glucose = 1200 
glucose_inflow = 1 

initial_antibiotic = 0 
antibiotic_intensity = 3 
antibiotic_decay = 0.03 
antibiotic_inflow = 0 
antibiotic_start_time = 50 

C0_1 = 10 
C0_2 = 10 

dt = 0.1 
T = 200 
N_steps = int(T / dt)

C1 = np.zeros(N_steps)
C2 = np.zeros(N_steps)
glucose_level = np.zeros(N_steps)
antibiotic_level = np.zeros(N_steps)
growth_rate_1 = np.zeros(N_steps)
growth_rate_2 = np.zeros(N_steps)
mortality_rate_1 = np.zeros(N_steps)
mortality_rate_2 = np.zeros(N_steps)

C1[0] = C0_1
C2[0] = C0_2
glucose_level[0] = initial_glucose
antibiotic_level[0] = 0
growth_rate_1[0] = rmax_1 * glucose_level[0] / (K_1 + glucose_level[0])
growth_rate_2[0] = rmax_2 * glucose_level[0] / (K_2 + glucose_level[0])
mortality_rate_1[0] = m0_1
mortality_rate_2[0] = m0_2

for i in range(1, N_steps):
    current_time = i * dt
    
    r_1 = rmax_1 * glucose_level[i-1] / (K_1 + glucose_level[i-1])
    r_2 = rmax_2 * glucose_level[i-1] / (K_2 + glucose_level[i-1])
    
    if current_time < antibiotic_start_time:
        antibiotic_level[i] = 0
    else:
        if antibiotic_level[i-1] == 0: # Premier pas après l'injection
            antibiotic_level[i] = initial_antibiotic
        else:
            antibiotic_level[i] = antibiotic_level[i-1] * (1 - antibiotic_decay * dt) + antibiotic_inflow * dt
    
    if antibiotic_level[i] > 0:
        antibiotic_effect_1 = antibiotic_intensity * (antibiotic_level[i] / initial_antibiotic) * (1 - resistance_1)
        antibiotic_effect_2 = antibiotic_intensity * (antibiotic_level[i] / initial_antibiotic) * (1 - resistance_2)
    else:
        antibiotic_effect_1 = 0
        antibiotic_effect_2 = 0
        
    m_1 = m0_1 * (1 + antibiotic_effect_1)
    m_2 = m0_2 * (1 + antibiotic_effect_2)
    
    C1[i] = C1[i-1] + dt * (r_1 - m_1) * C1[i-1]
    C2[i] = C2[i-1] + dt * (r_2 - m_2) * C2[i-1]
    
    glucose_consumption = (r_1 * C1[i-1] + r_2 * C2[i-1])
    glucose_level[i] = glucose_level[i-1] - dt * glucose_consumption + glucose_inflow * dt

    growth_rate_1[i] = r_1
    growth_rate_2[i] = r_2
    mortality_rate_1[i] = m_1
    mortality_rate_2[i] = m_2

time = np.linspace(0, T, N_steps)
max_growth = max(np.max(growth_rate_1), np.max(growth_rate_2))
max_mortality = max(np.max(mortality_rate_1), np.max(mortality_rate_2))
y_max_rates = max(max_growth, max_mortality) * 1.1 # +10% de marge

plt.figure(figsize=(12, 15))

plt.subplot(5, 1, 1)
plt.plot(time, C1, label=f'Souche 1 (Résistance = {resistance_1})', color='blue')
plt.plot(time, C2, label=f'Souche 2 (Résistance = {resistance_2})', color='orange')
plt.axvline(x=antibiotic_start_time, color='red', linestyle='--', label=f'Injection antibiotique (t={antibiotic_start_time}h)')
plt.title('Compétition entre 2 souches avec antibiotique injecté à t=500h')
plt.ylabel('10³ cellules/mL')
plt.legend()
plt.grid(True)
plt.ylim(bottom=0)

plt.subplot(5, 1, 2)
plt.plot(time, glucose_level, label='Glucose', color='green')
plt.title('Concentration de glucose')
plt.ylabel('g/L')
plt.legend()
plt.grid(True)
plt.ylim(bottom=0)

plt.subplot(5, 1, 3)
plt.plot(time, antibiotic_level, label='Antibiotique', color='red')
plt.axvline(x=antibiotic_start_time, color='black', linestyle=':', label=f'Début injection (t={antibiotic_start_time}h)')
plt.title(f'Concentration d\'antibiotique (Décroissance = {antibiotic_decay} h⁻¹, Inflow = {antibiotic_inflow}mg/L/h)')
plt.ylabel('mg/L')
plt.legend()
plt.grid(True)
plt.ylim(bottom=0)
plt.subplot(5, 1, 4)
plt.plot(time, growth_rate_1, label='Taux de croissance (Souche 1)', color='blue', linestyle='--')
plt.plot(time, mortality_rate_1, label='Taux de mortalité (Souche 1)', color='blue', linestyle=':')
plt.title('Taux de croissance et mortalité - Souche 1')
plt.ylabel('h⁻¹')
plt.legend()
plt.grid(True)
plt.ylim(bottom=0, top=y_max_rates) 

plt.subplot(5, 1, 5)
plt.plot(time, growth_rate_2, label='Taux de croissance (Souche 2)', color='orange', linestyle='--')
plt.plot(time, mortality_rate_2, label='Taux de mortalité (Souche 2)', color='orange', linestyle=':')
plt.title('Taux de croissance et mortalité - Souche 2')
plt.xlabel('Temps (heures)')
plt.ylabel('h⁻¹')
plt.legend()
plt.grid(True)
plt.ylim(bottom=0, top=y_max_rates)
            
plt.tight_layout()
plt.show()

# %% [markdown]
# Aprés l'ibnjection: la mortalité augmente brutalement, les populations chutent fortemen, certaines peuvent disparaitre.
#
# L'antibiotique agit comme une pression de la selection.
#
# Avecrésistance de la souche 1; sa mortalité augmente peu, elle survit; la souche 2 diminue fortement
#
# Avec T = 2000 sur le long terme; la souche résistance prend totalement l'avantage, la souche sensible peut disparaitre
#
# Avec pollution même une faible quantité d'antibiotique favorise élimine progressivement les bactéries sensibles.
#
# Cela montre que la pollution antibiotique sélectionne les résistances

# %%
import numpy as np
import matplotlib.pyplot as plt

rmax_1 = 0.15 
m0_1 = 0.07
K_1 = 800
resistance_1 = 0.8 

rmax_2 = 0.15 
m0_2 = 0.07 
K_2 = 650 
resistance_2 = 0 

initial_glucose = 1200 
glucose_inflow = 1 

initial_antibiotic = 0 
antibiotic_intensity = 3 
antibiotic_decay = 0.03 
antibiotic_inflow = 0 
antibiotic_start_time = 50 

C0_1 = 10 
C0_2 = 10 

dt = 0.1 
T = 200 
N_steps = int(T / dt)

C1 = np.zeros(N_steps)
C2 = np.zeros(N_steps)
glucose_level = np.zeros(N_steps)
antibiotic_level = np.zeros(N_steps)
growth_rate_1 = np.zeros(N_steps)
growth_rate_2 = np.zeros(N_steps)
mortality_rate_1 = np.zeros(N_steps)
mortality_rate_2 = np.zeros(N_steps)

C1[0] = C0_1
C2[0] = C0_2
glucose_level[0] = initial_glucose
antibiotic_level[0] = 0
growth_rate_1[0] = rmax_1 * glucose_level[0] / (K_1 + glucose_level[0])
growth_rate_2[0] = rmax_2 * glucose_level[0] / (K_2 + glucose_level[0])
mortality_rate_1[0] = m0_1
mortality_rate_2[0] = m0_2

for i in range(1, N_steps):
    current_time = i * dt
    
    r_1 = rmax_1 * glucose_level[i-1] / (K_1 + glucose_level[i-1])
    r_2 = rmax_2 * glucose_level[i-1] / (K_2 + glucose_level[i-1])
    
    if current_time < antibiotic_start_time:
        antibiotic_level[i] = 0
    else:
        if antibiotic_level[i-1] == 0: # Premier pas après l'injection
            antibiotic_level[i] = initial_antibiotic
        else:
            antibiotic_level[i] = antibiotic_level[i-1] * (1 - antibiotic_decay * dt) + antibiotic_inflow * dt
    
    if antibiotic_level[i] > 0:
        antibiotic_effect_1 = antibiotic_intensity * (antibiotic_level[i] / initial_antibiotic) * (1 - resistance_1)
        antibiotic_effect_2 = antibiotic_intensity * (antibiotic_level[i] / initial_antibiotic) * (1 - resistance_2)
    else:
        antibiotic_effect_1 = 0
        antibiotic_effect_2 = 0
        
    m_1 = m0_1 * (1 + antibiotic_effect_1)
    m_2 = m0_2 * (1 + antibiotic_effect_2)
    
    C1[i] = C1[i-1] + dt * (r_1 - m_1) * C1[i-1]
    C2[i] = C2[i-1] + dt * (r_2 - m_2) * C2[i-1]
    
    glucose_consumption = (r_1 * C1[i-1] + r_2 * C2[i-1])
    glucose_level[i] = glucose_level[i-1] - dt * glucose_consumption + glucose_inflow * dt

    growth_rate_1[i] = r_1
    growth_rate_2[i] = r_2
    mortality_rate_1[i] = m_1
    mortality_rate_2[i] = m_2

time = np.linspace(0, T, N_steps)
max_growth = max(np.max(growth_rate_1), np.max(growth_rate_2))
max_mortality = max(np.max(mortality_rate_1), np.max(mortality_rate_2))
y_max_rates = max(max_growth, max_mortality) * 1.1 # +10% de marge

plt.figure(figsize=(12, 15))

plt.subplot(5, 1, 1)
plt.plot(time, C1, label=f'Souche 1 (Résistance = {resistance_1})', color='blue')
plt.plot(time, C2, label=f'Souche 2 (Résistance = {resistance_2})', color='orange')
plt.axvline(x=antibiotic_start_time, color='red', linestyle='--', label=f'Injection antibiotique (t={antibiotic_start_time}h)')
plt.title('Compétition entre 2 souches avec antibiotique injecté à t=500h')
plt.ylabel('10³ cellules/mL')
plt.legend()
plt.grid(True)
plt.ylim(bottom=0)

plt.subplot(5, 1, 2)
plt.plot(time, glucose_level, label='Glucose', color='green')
plt.title('Concentration de glucose')
plt.ylabel('g/L')
plt.legend()
plt.grid(True)
plt.ylim(bottom=0)

plt.subplot(5, 1, 3)
plt.plot(time, antibiotic_level, label='Antibiotique', color='red')
plt.axvline(x=antibiotic_start_time, color='black', linestyle=':', label=f'Début injection (t={antibiotic_start_time}h)')
plt.title(f'Concentration d\'antibiotique (Décroissance = {antibiotic_decay} h⁻¹, Inflow = {antibiotic_inflow}mg/L/h)')
plt.ylabel('mg/L')
plt.legend()
plt.grid(True)
plt.ylim(bottom=0)
plt.subplot(5, 1, 4)
plt.plot(time, growth_rate_1, label='Taux de croissance (Souche 1)', color='blue', linestyle='--')
plt.plot(time, mortality_rate_1, label='Taux de mortalité (Souche 1)', color='blue', linestyle=':')
plt.title('Taux de croissance et mortalité - Souche 1')
plt.ylabel('h⁻¹')
plt.legend()
plt.grid(True)
plt.ylim(bottom=0, top=y_max_rates) 

plt.subplot(5, 1, 5)
plt.plot(time, growth_rate_2, label='Taux de croissance (Souche 2)', color='orange', linestyle='--')
plt.plot(time, mortality_rate_2, label='Taux de mortalité (Souche 2)', color='orange', linestyle=':')
plt.title('Taux de croissance et mortalité - Souche 2')
plt.xlabel('Temps (heures)')
plt.ylabel('h⁻¹')
plt.legend()
plt.grid(True)
plt.ylim(bottom=0, top=y_max_rates)
            
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

rmax_1 = 0.15 
m0_1 = 0.07
K_1 = 800
resistance_1 = 0 

rmax_2 = 0.15 
m0_2 = 0.07 
K_2 = 650 
resistance_2 = 0 

initial_glucose = 1200 
glucose_inflow = 1 

initial_antibiotic = 0 
antibiotic_intensity = 3 
antibiotic_decay = 0.03 
antibiotic_inflow = 0.05 
antibiotic_start_time = 50 

C0_1 = 10 
C0_2 = 10 

dt = 0.1 
T = 2000 
N_steps = int(T / dt)

C1 = np.zeros(N_steps)
C2 = np.zeros(N_steps)
glucose_level = np.zeros(N_steps)
antibiotic_level = np.zeros(N_steps)
growth_rate_1 = np.zeros(N_steps)
growth_rate_2 = np.zeros(N_steps)
mortality_rate_1 = np.zeros(N_steps)
mortality_rate_2 = np.zeros(N_steps)

C1[0] = C0_1
C2[0] = C0_2
glucose_level[0] = initial_glucose
antibiotic_level[0] = 0
growth_rate_1[0] = rmax_1 * glucose_level[0] / (K_1 + glucose_level[0])
growth_rate_2[0] = rmax_2 * glucose_level[0] / (K_2 + glucose_level[0])
mortality_rate_1[0] = m0_1
mortality_rate_2[0] = m0_2

for i in range(1, N_steps):
    current_time = i * dt
    
    r_1 = rmax_1 * glucose_level[i-1] / (K_1 + glucose_level[i-1])
    r_2 = rmax_2 * glucose_level[i-1] / (K_2 + glucose_level[i-1])
    
    if current_time < antibiotic_start_time:
        antibiotic_level[i] = 0
    else:
        if antibiotic_level[i-1] == 0: 
            antibiotic_level[i] = initial_antibiotic
        else:
            antibiotic_level[i] = antibiotic_level[i-1] * (1 - antibiotic_decay * dt) + antibiotic_inflow * dt
    
    if antibiotic_level[i] > 0:
        antibiotic_effect_1 = antibiotic_intensity * (antibiotic_level[i] / initial_antibiotic) * (1 - resistance_1)
        antibiotic_effect_2 = antibiotic_intensity * (antibiotic_level[i] / initial_antibiotic) * (1 - resistance_2)
    else:
        antibiotic_effect_1 = 0
        antibiotic_effect_2 = 0
        
    m_1 = m0_1 * (1 + antibiotic_effect_1)
    m_2 = m0_2 * (1 + antibiotic_effect_2)
    
    C1[i] = C1[i-1] + dt * (r_1 - m_1) * C1[i-1]
    C2[i] = C2[i-1] + dt * (r_2 - m_2) * C2[i-1]
    
    glucose_consumption = (r_1 * C1[i-1] + r_2 * C2[i-1])
    glucose_level[i] = glucose_level[i-1] - dt * glucose_consumption + glucose_inflow * dt

    growth_rate_1[i] = r_1
    growth_rate_2[i] = r_2
    mortality_rate_1[i] = m_1
    mortality_rate_2[i] = m_2

time = np.linspace(0, T, N_steps)
max_growth = max(np.max(growth_rate_1), np.max(growth_rate_2))
max_mortality = max(np.max(mortality_rate_1), np.max(mortality_rate_2))
y_max_rates = max(max_growth, max_mortality) * 1.1 

plt.figure(figsize=(12, 15))

plt.subplot(5, 1, 1)
plt.plot(time, C1, label=f'Souche 1 (Résistance = {resistance_1})', color='blue')
plt.plot(time, C2, label=f'Souche 2 (Résistance = {resistance_2})', color='orange')
plt.axvline(x=antibiotic_start_time, color='red', linestyle='--', label=f'Injection antibiotique (t={antibiotic_start_time}h)')
plt.title('Compétition entre 2 souches avec antibiotique injecté à t=500h')
plt.ylabel('10³ cellules/mL')
plt.legend()
plt.grid(True)
plt.ylim(bottom=0)

plt.subplot(5, 1, 2)
plt.plot(time, glucose_level, label='Glucose', color='green')
plt.title('Concentration de glucose')
plt.ylabel('g/L')
plt.legend()
plt.grid(True)
plt.ylim(bottom=0)

plt.subplot(5, 1, 3)
plt.plot(time, antibiotic_level, label='Antibiotique', color='red')
plt.axvline(x=antibiotic_start_time, color='black', linestyle=':', label=f'Début injection (t={antibiotic_start_time}h)')
plt.title(f'Concentration d\'antibiotique (Décroissance = {antibiotic_decay} h⁻¹, Inflow = {antibiotic_inflow}mg/L/h)')
plt.ylabel('mg/L')
plt.legend()
plt.grid(True)
plt.ylim(bottom=0)
plt.subplot(5, 1, 4)
plt.plot(time, growth_rate_1, label='Taux de croissance (Souche 1)', color='blue', linestyle='--')
plt.plot(time, mortality_rate_1, label='Taux de mortalité (Souche 1)', color='blue', linestyle=':')
plt.title('Taux de croissance et mortalité - Souche 1')
plt.ylabel('h⁻¹')
plt.legend()
plt.grid(True)
plt.ylim(bottom=0, top=y_max_rates) 

plt.subplot(5, 1, 5)
plt.plot(time, growth_rate_2, label='Taux de croissance (Souche 2)', color='orange', linestyle='--')
plt.plot(time, mortality_rate_2, label='Taux de mortalité (Souche 2)', color='orange', linestyle=':')
plt.title('Taux de croissance et mortalité - Souche 2')
plt.xlabel('Temps (heures)')
plt.ylabel('h⁻¹')
plt.legend()
plt.grid(True)
plt.ylim(bottom=0, top=y_max_rates)
            
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

rmax_1 = 0.15 
m0_1 = 0.07
K_1 = 800
resistance_1 = 0 

rmax_2 = 0.15 
m0_2 = 0.07 
K_2 = 650 
resistance_2 = 0 

initial_glucose = 1200 
glucose_inflow = 1 

initial_antibiotic = 0 
antibiotic_intensity = 3 
antibiotic_decay = 0.03 
antibiotic_inflow = 0 
antibiotic_start_time = 50 

C0_1 = 10 
C0_2 = 10 

dt = 0.1 
T = 200 
N_steps = int(T / dt)

C1 = np.zeros(N_steps)
C2 = np.zeros(N_steps)
glucose_level = np.zeros(N_steps)
antibiotic_level = np.zeros(N_steps)
growth_rate_1 = np.zeros(N_steps)
growth_rate_2 = np.zeros(N_steps)
mortality_rate_1 = np.zeros(N_steps)
mortality_rate_2 = np.zeros(N_steps)

C1[0] = C0_1
C2[0] = C0_2
glucose_level[0] = initial_glucose
antibiotic_level[0] = 0
growth_rate_1[0] = rmax_1 * glucose_level[0] / (K_1 + glucose_level[0])
growth_rate_2[0] = rmax_2 * glucose_level[0] / (K_2 + glucose_level[0])
mortality_rate_1[0] = m0_1
mortality_rate_2[0] = m0_2

for i in range(1, N_steps):
    current_time = i * dt
    
    r_1 = rmax_1 * glucose_level[i-1] / (K_1 + glucose_level[i-1])
    r_2 = rmax_2 * glucose_level[i-1] / (K_2 + glucose_level[i-1])
    
    if current_time < antibiotic_start_time:
        antibiotic_level[i] = 0
    else:
        if antibiotic_level[i-1] == 0: # Premier pas après l'injection
            antibiotic_level[i] = initial_antibiotic
        else:
            antibiotic_level[i] = antibiotic_level[i-1] * (1 - antibiotic_decay * dt) + antibiotic_inflow * dt
    
    if antibiotic_level[i] > 0:
        antibiotic_effect_1 = antibiotic_intensity * (antibiotic_level[i] / initial_antibiotic) * (1 - resistance_1)
        antibiotic_effect_2 = antibiotic_intensity * (antibiotic_level[i] / initial_antibiotic) * (1 - resistance_2)
    else:
        antibiotic_effect_1 = 0
        antibiotic_effect_2 = 0
        
    m_1 = m0_1 * (1 + antibiotic_effect_1)
    m_2 = m0_2 * (1 + antibiotic_effect_2)
    
    C1[i] = C1[i-1] + dt * (r_1 - m_1) * C1[i-1]
    C2[i] = C2[i-1] + dt * (r_2 - m_2) * C2[i-1]
    
    glucose_consumption = (r_1 * C1[i-1] + r_2 * C2[i-1])
    glucose_level[i] = glucose_level[i-1] - dt * glucose_consumption + glucose_inflow * dt

    growth_rate_1[i] = r_1
    growth_rate_2[i] = r_2
    mortality_rate_1[i] = m_1
    mortality_rate_2[i] = m_2

time = np.linspace(0, T, N_steps)
max_growth = max(np.max(growth_rate_1), np.max(growth_rate_2))
max_mortality = max(np.max(mortality_rate_1), np.max(mortality_rate_2))
y_max_rates = max(max_growth, max_mortality) * 1.1 # +10% de marge

plt.figure(figsize=(12, 15))

plt.subplot(5, 1, 1)
plt.plot(time, C1, label=f'Souche 1 (Résistance = {resistance_1})', color='blue')
plt.plot(time, C2, label=f'Souche 2 (Résistance = {resistance_2})', color='orange')
plt.axvline(x=antibiotic_start_time, color='red', linestyle='--', label=f'Injection antibiotique (t={antibiotic_start_time}h)')
plt.title('Compétition entre 2 souches avec antibiotique injecté à t=500h')
plt.ylabel('10³ cellules/mL')
plt.legend()
plt.grid(True)
plt.ylim(bottom=0)

plt.subplot(5, 1, 2)
plt.plot(time, glucose_level, label='Glucose', color='green')
plt.title('Concentration de glucose')
plt.ylabel('g/L')
plt.legend()
plt.grid(True)
plt.ylim(bottom=0)

plt.subplot(5, 1, 3)
plt.plot(time, antibiotic_level, label='Antibiotique', color='red')
plt.axvline(x=antibiotic_start_time, color='black', linestyle=':', label=f'Début injection (t={antibiotic_start_time}h)')
plt.title(f'Concentration d\'antibiotique (Décroissance = {antibiotic_decay} h⁻¹, Inflow = {antibiotic_inflow}mg/L/h)')
plt.ylabel('mg/L')
plt.legend()
plt.grid(True)
plt.ylim(bottom=0)
plt.subplot(5, 1, 4)
plt.plot(time, growth_rate_1, label='Taux de croissance (Souche 1)', color='blue', linestyle='--')
plt.plot(time, mortality_rate_1, label='Taux de mortalité (Souche 1)', color='blue', linestyle=':')
plt.title('Taux de croissance et mortalité - Souche 1')
plt.ylabel('h⁻¹')
plt.legend()
plt.grid(True)
plt.ylim(bottom=0, top=y_max_rates) 

plt.subplot(5, 1, 5)
plt.plot(time, growth_rate_2, label='Taux de croissance (Souche 2)', color='orange', linestyle='--')
plt.plot(time, mortality_rate_2, label='Taux de mortalité (Souche 2)', color='orange', linestyle=':')
plt.title('Taux de croissance et mortalité - Souche 2')
plt.xlabel('Temps (heures)')
plt.ylabel('h⁻¹')
plt.legend()
plt.grid(True)
plt.ylim(bottom=0, top=y_max_rates)
            
plt.tight_layout()
plt.show()
